# %%
from dotenv import load_dotenv
import os

load_dotenv()

openai_api_key=os.getenv("OPENAI_API_KEY")
print("API Key is Loaded: ", openai_api_key is not None)
# Out:
# API Key is Loaded:  True

# %%
from crewai.llm import LLM

# %%
llm=LLM(
    model="gpt-5.1",
    temperature=0.1
)
response=llm.call("What is Crew AI?")
print(response)
# Out:
# “Crew AI” usually refers to **CrewAI**, an open‑source Python framework for building *multi‑agent* AI systems—where several specialized AI agents work together like a “crew” to complete complex tasks.
#
# Key points:
#
# - **Multi‑agent orchestration**:
#   You define multiple agents (e.g., “researcher,” “writer,” “coder,” “reviewer”), each with its own role, tools, and instructions. CrewAI coordinates how they collaborate and pass work between each other.
#
# - **Python-based framework**:
#   You write code in Python to:
#   - Define agents (with LLMs, tools, and goals)
#   - Define tasks (what needs to be done, expected outputs)
#   - Define a “crew” (which agents handle which tasks and in what order or structure)
#
# - **Tool and LLM integration**:
#   It can plug into different large language models (OpenAI, Anthropic, etc.) and tools (web search, code execution, APIs, databases), so agents can act beyond pure text generation.
#
# - **Use cases**:
#   - Research pipelines (one agent gathers info, another summarizes, another critiques)
#   - Content creation workflows
#   - Data analysis and reporting
#   - Software development assistants (planner, coder, tester agents)
#
# - **Open source**:
#   Available on GitHub as `crewai` (often installed via `pip install crewai`), with examples and templates for common workflows.
#
# If you tell me your use case (e.g., “I want agents to research and draft blog posts” or “I want a coding crew”), I can show a minimal code example of how CrewAI would be set up for that.

# %%
from crewai import Agent, Task, Crew

AI_Email_Writing_Expert=Agent(
    role="AI Email Writing Expert",
    goal="Enhance email content to ensure it is professional, concise and effectively communicates the intended message",
    backstory="A polished communcation strategist dedicated to enhancing email quality for better engagement and professionalism",
    verbose=True,
    llm=llm
)

original_email="""
Hi team, just want to following up with you that the deadline of the projects is coming soon, so where we are 
in the work, try to complete ASAP.
Let me know if you facing any blocker in the work.
Thanki you
"""

improve_email_task=Task(
    description=f"""Rewrite the following email to make it more professional and engaging
    Expand abbreviations:
    '''{original_email}'''""",
    agent=AI_Email_Writing_Expert,
    expected_output="A well-structured, professionally written email with clear formatting and concise content,",
    async_execution=False,
)

crew=Crew(
    agents=[AI_Email_Writing_Expert],
    tasks=[improve_email_task],
    verbose=True
)

result=crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d3fc5fd3-6c3b-4902-9807-b539c6801413                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI